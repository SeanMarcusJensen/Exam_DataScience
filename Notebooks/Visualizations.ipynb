# %%
import pandas as pd
from Shared.helpers import heat_map
from Shared.preprocesser import DataframeProcesser
from Shared.visualizer import Visualizer
import matplotlib.pyplot as plt

# %%
dataframe = pd.read_csv('Data/Titanic.csv')
processer = DataframeProcesser(dataset=dataframe)
visualizer = Visualizer(dataframe)

# %%
visualizer.corr_heatmap()
# Out:
# <AxesSubplot:title={'center':'Correlation matrix'}>

# %%
processer.normalize('minmax').head()
# Out:
#    PassengerId  Survived  Pclass       Age  SibSp  Parch      Fare
# 0     0.000000       0.0     1.0  0.271174  0.125    0.0  0.014151
# 1     0.001124       1.0     0.0  0.472229  0.125    0.0  0.139136
# 2     0.002247       1.0     1.0  0.321438  0.000    0.0  0.015469
# 3     0.003371       1.0     0.0  0.434531  0.125    0.0  0.103644
# 4     0.004494       0.0     1.0  0.434531  0.000    0.0  0.015713

# %%
visualizer.make_histogram('Age', 5)

# %% [markdown]
# # Correlation
# ## Pclass and Fare
# We clearly see that the price is pretty much the same for the middle- and lower class, but the price for the first class is vary.
#
# ##

# %%
visualizer.update_df(dataframe)
visualizer.make_scatter_plot('Pclass', 'Fare')

# %%
visualizer.make_histogram('SibSp', 1)

# %%
visualizer.make_histogram('Parch', 1)

# %%
plt.hist(dataframe[dataframe['Parch']], 5, density=True, histtype='bar', color=['red'], stacked=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/seanmarcusjensen/development/DataScience/Notebooks/Visualizations.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/seanmarcusjensen/development/DataScience/Notebooks/Visualizations.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> plt.hist(dataframe[dataframe['Parch']], 5, density=True, histtype='bar', color=['red'], stacked=True)
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# ...
